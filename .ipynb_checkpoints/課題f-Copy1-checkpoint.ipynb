# %% [markdown]
# https://pythontutor.com/
#
# https://replit.com/

# %% [markdown]
# # 探索

# %%
// 線形探索
#include <stdio.h>

int linearSearch(int data[], int n, int x) ;

int main(){
    int x, index, data[6] = {5, 6, 3, 1, 8, 9};
  
    printf("検索したいデータを入力してください -> ");
    scanf("%d", &x);
    
    index = linearSearch(data, 6, x);
    printf("index = %d\n", index);
}

// 線形探索法　配列の先頭から順番に調べていく
// 引数は探索対象の配列，　配列の要素数，　探索する値
int linearSearch(int data[], int n, int x) {
    int i;
    for(i = 0; i < n; i++) {
        if(data[i] == x) {
            return i; // 見つかればindexを返す
        }
    }
    return -1; // 見つからなければ-1を返す
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmplki26en8.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# 検索したいデータを入力してください -> 3
# index = 2

# %%
// 番兵を用いた線形探索
#include <stdio.h>

int linearSearch(int data[], int n, int x) ;

int main(){
    int x, index, data[6] = {5, 6, 3, 1, 8, 9};
    
    printf("検索したいデータを入力してください -> ");
    scanf("%d", &x);
    
    index = linearSearch(data, 6, x);
    printf("index = %d\n", index);
}

// 線形探索法 + 番兵　配列の先頭から順番に調べていく
// 引数は探索対象の配列，配列の要素数，探索する値
int linearSearch(int data[], int n, int x) {
    int i, data2[n+1];
    for(i = 0; i < n; i++)
        data2[i] = data[i];
    data2[n] = x;
    
    i = 0;
    while(1){
        
        if(data2[i] == x )
            break;
        i++;
    }
    
    if (i == n)
        return -1;  // 見つからなければ-1を返す
    
    return i;   // 見つかればindexを返す
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmp3bvoet60.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# 検索したいデータを入力してください -> 8
# index = 4

# %% [markdown]
# ##
#
# 以下のプログラムは，**二分法**で配列からデータを探索するプログラムである．
#
# 実行例と同様の出力となるように，二分法を行うBinarySearch関数を完成させよ．
#
#
# ---
# ```c
# #include <stdio.h>
#
# int BinarySearch( /* コードを書く */ ) ;
#
# int main(){
#     int i, x, index, data[10] = {5, 8, 9, 12, 16, 19, 23, 25, 29, 30};
#
#     printf("data[10]: ");
#     for(i=0;i<10;i++){
#         printf("%d ",data[i]);
#     }
#     printf("\n");
#
#     printf("検索したいデータを入力してください -> ");
#     scanf("%d", &x);
#
#     index = BinarySearch(data, 10, x);
#     printf("index = %d\n", index);
# }
#
# // 二分法
# // 引数は探索対象の配列, 配列の要素数，探索する値
# int BinarySearch( /* コードを書く */ ) {
#     // コードを書く
# }
# ```
# ---
#
# - 実行例1 (探索成功)
# ```
# data[10]: 5 8 9 12 16 19 23 25 29 30
# 検索したいデータを入力してください -> 25
# x = 25: left=0 mid=4 right=9
# x = 25: left=5 mid=7 right=9
# index = 7
# ```
#
# - 実行例2 (探索失敗)
# ```
# data[10]: 5 8 9 12 16 19 23 25 29 30
# 検索したいデータを入力してください -> 24
# x = 24: left=0 mid=4 right=9
# x = 24: left=5 mid=7 right=9
# x = 24: left=5 mid=5 right=6
# x = 24: left=6 mid=6 right=6
# index = -1
# ```

# %%
// f1-1.c 解答
// 二分法
#include <stdio.h>

int BinarySearch(int data[], int n, int x) ;

int main(){
    int i, x, index, data[10] = {5, 8, 9, 12, 16, 19, 23, 25, 29, 30};
    
    printf("data[10]: ");
    for(i=0;i<10;i++){
        printf("%d ",data[i]);
    }
    printf("\n");
    
    printf("検索したいデータを入力してください -> ");
    scanf("%d", &x);
    
    index = BinarySearch(data, 10, x);
    printf("index = %d\n", index);
}

// 二分法
// 引数は探索対象の配列, 配列の要素数，探索する値
int BinarySearch(int data[], int n, int x) {
    int left, right, mid;
    
    // 添字の範囲を初期化
    left = 0;
    right = n-1;
    
    // 値が見つかるまで繰り返す
    while (left <= right) {
        mid = (left + right) / 2;
        // 添字の変化を表示
        printf("x = %d: left=%d mid=%d right=%d\n", x, left, mid, right) ;
        // 値が見つかればループを抜ける
        if (data[mid] == x) {
            return mid; // midのindexを返す
        }
        else if (data[mid] < x) {
            left = mid + 1; // 探索範囲を右半分にしぼり込む
        }
        else {
            right = mid - 1; // 探索範囲を左半分にしぼり込む
        }
    }
    
    return -1;  // 見つからなければ-1を返す
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmp71owyk5d.c:3:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# data[10]: 5 8 9 12 16 19 23 25 29 30
# 検索したいデータを入力してください -> 25
# x = 25: left=0 mid=4 right=9
# x = 25: left=5 mid=7 right=9
# index = 7

# %% [markdown]
# ##
#
# 以下のプログラムは，**番兵を用いた線形探索**で構造体配列からデータを探索するプログラムである．
#
# 構造体は`name`と`score`のメンバを持つが，`name`をキーとして探索を行う．
#
# 実行例と同様の出力となるように，set_data関数とLinearSearch関数を完成させよ．
#
# ---
# ```c
# #include <stdio.h>
# #include <string.h>
#
# typedef struct{
#     char name[5]; // 名前
#     int score;  // 得点
# }student_t;
#
# student_t set_data( /* コードを書く */ );
# int LinearSearch( /* コードを書く */ );
#
# int main(){
#     int i, result;
#     char target[5] = "Y.O"; // 検索対象の名前
#     student_t student[5];
#     //データを構造体に代入
#     student[0] = set_data("R.A",100);
#     student[1] = set_data("S.K",69);
#     student[2] = set_data("T.Y",80);
#     student[3] = set_data("Y.O",92);
#     student[4] = set_data("A.F",35);
#
#     for(i=0;i<5;i++){
#         printf("名前 %s, 得点 %d\n",student[i].name,student[i].score);
#     }
#
#     result = LinearSearch(target,student,5);
#
#     // 探索のkeyはname
#     printf("\n探す対象 = %s\n\n",target);
#
#     if(result == -1){
#         printf("見つかりませんでした\n");
#     }
#     else{
#         printf("添え字番号%d番目で発見\n",result);
#         printf("名前 %s, 得点 %d\n",student[result].name,student[result].score);
#     }
#
#     return 0;
# }
#
# student_t set_data( /* コードを書く */ ){
#
#     //コードを書く
#
# }
#
# int LinearSearch( /* コードを書く */ ){
#
#     //コードを書く
#
# }
# ```
# ---
#
# - 実行例1 (探索成功)
#
# ```
# 名前 R.A, 得点 100
# 名前 S.K, 得点 69
# 名前 T.Y, 得点 80
# 名前 Y.O, 得点 92
# 名前 A.F, 得点 35
#
# 探す対象 = Y.O
#
# 添え字番号3番目で発見
# 名前 Y.O, 得点 92
# ```
#
# - 実行例2 (探索失敗)
#
# ```
# 名前 R.A, 得点 100
# 名前 S.K, 得点 69
# 名前 T.Y, 得点 80
# 名前 Y.O, 得点 92
# 名前 A.F, 得点 35
#
# 探す対象 = J.T
#
# 見つかりませんでした
# ```

# %%
//f1-2.c 解答
#include <stdio.h>
#include <string.h>

typedef struct{
    char name[5]; // 名前
    int score;  // 得点
}student_t;

student_t set_data(char name[], int score);
int LinearSearch(char target[], student_t *student, int n);

int main(){
    int i, result;
    char target[5] = "Y.O"; // 検索対象の名前 (keyはname)
    student_t student[5];
    //データを構造体に代入
    student[0] = set_data("R.A",100);
    student[1] = set_data("S.K",69);
    student[2] = set_data("T.Y",80);
    student[3] = set_data("Y.O",92);
    student[4] = set_data("A.F",35);
    
    for(i=0;i<5;i++){
        printf("名前 %s, 得点 %d\n",student[i].name,student[i].score);
    }

    result = LinearSearch(target,student,5);

    // 探索のkeyはname
    printf("\n探す対象 = %s\n\n",target);

    if(result == -1){
        printf("見つかりませんでした\n");
    }
    else{
        printf("添え字番号%d番目で発見\n",result);
        printf("名前 %s, 得点 %d\n",student[result].name,student[result].score);
    }

    return 0;
}

student_t set_data(char name[], int score){
    student_t tmp;
    strcpy(tmp.name,name);
    tmp.score = score;
    return tmp;
}

int LinearSearch(char target[], student_t *student, int n){
    int i = 0;
    student_t student2[n+1];
    
    for(i=0;i<n;i++){
        student2[i] = student[i];
    }
    // 末尾に探索対象のデータのキー(name)を追加
    strcpy(student2[n].name,target);

    i=0;
    while(1){
         if(strcmp(student2[i].name,target)==0)
             break;
        
        i++;
    }
    
    if(i==n)
        return -1;  // 見つからなければ-1を返す (番兵に到達)
    else
        return i;   // 見つかればindexを返す

}
# Out:
# 名前 R.A, 得点 100
# 名前 S.K, 得点 69
# 名前 T.Y, 得点 80
# 名前 Y.O, 得点 92
# 名前 A.F, 得点 35
#
# 探す対象 = Y.O
#
# 添え字番号3番目で発見
# 名前 Y.O, 得点 92

# %% [markdown]
# #  スタックとキュー

# %% [markdown]
# ##
#
# 以下は配列を用いた**スタック**のプログラムである．
#
# 課題fの説明のスライドを参考にし, 正しく動作するプログラムを完成させよ．
#
#
# 実行結果は，
#
# - [f2-1の実行例1](課題f2-1の実行例1.txt)
# - [f2-1の実行例2](課題f2-1の実行例1.txt)
#
# と一致するようにすること．
#
# ---
# ```c
# #include <stdio.h>
# #include <stdlib.h>
#
# /* スタックに入るデータの上限 */
# #define MAX_STACK_NUM 10
#
# /* スタックの構造体 */
# typedef struct{
#     /* スタックされているデータの数（スタックトップ） */
#     int num;
#     /* スタックされているデータ */
#     int data[MAX_STACK_NUM];
# } STACK_T;
#
# // プロトタイプ宣言
# void initStack(STACK_T *stack);
# void printStack(STACK_T *stack);
# void push( /* コードを書く */ );
# int pop( /* コードを書く */ );
#
# int main(){
#
#     int m;
#     int input;
#     int output;
#     STACK_T stack;
#
#     /* スタックを初期化 */
#     initStack(&stack);
#
#     while(1){
#
#         printf("\n----------\n");
#         printf("メニュー\n 1:PUSH\n 2:POP\n 3:スタック表示\n それ以外:終了\n");
#         printf("----------\n");
#
#         printf("input > ");
#         scanf("%d", &m);
#
#         /* 選ばれたメニュー (m) に応じて処理を分岐 */
#         if(m == 1){
#             printf("PUSHする数は？（0以上の整数のみ可） > ");
#             scanf("%d", &input);
#             if(input < 0){
#                 printf("負の数は受け付けていません\n");
#                 continue;
#             }
#             printf("%dをPUSHします\n", input);
#              /* コードを書く */
#
#         }else if(m == 2){
#             printf("POPします\n");
#              /* コードを書く */
#
#             if(output != -1){
#                 printf("%dをPOPしました\n", output);
#             }
#
#         } else if(m == 3){
#             printf("スタックの中身を表示します\n");
#             printStack(&stack);
#
#         } else {
#             /* 1, 2, 3以外の場合は，while文を抜け出すためにbreakを実行 */
#             printf("終了します\n");
#             break;
#         }
#     }
#
#     return 0;
# }
#
# /* スタックを初期化する関数 */
# void initStack(STACK_T *stack){
#     int i = 0;
#     stack->num = 0; // スタックが空
#     for(i = 0; i < MAX_STACK_NUM; i++){
#         stack->data[i] = 0;
#     }
# }
#
# /* スタックの中身を表示 */
# void printStack(STACK_T *stack){
#     int i = 0;
#
#     printf("\n");
#     for(i = 0; i < stack->num; i++){
#         printf("| %d |\n", stack->data[stack->num-1-i]);
#         printf("-----\n");
#     }
#     printf("\n");
# }
#
# /* PUSHする関数 */
# void push( /* コードを書く */ ){
#
#     /* スタックが満杯なら何もせず関数終了 */
#     if(stack->num >= MAX_STACK_NUM){
#         printf("スタックが満杯でPUSHできません\n");
#         return;
#     }
#
#     // コードを書く
#
# }
#
# /* POPする関数 */
# int pop( /* コードを書く */ ){
#     int ret = 0;
#
#     /* スタックが空なら何もせずに関数終了 */
#     if(stack->num == 0){
#         printf("スタックが空です\n");
#         return -1;
#     }
#
#     // コードを書く
#
# }
#
#
# ```
# ---

# %%
// f2-1.c 解答
#include <stdio.h>
#include <stdlib.h>

/* スタックに入るデータの上限 */
#define MAX_STACK_NUM 10

/* スタックの構造体 */
typedef struct{
    /* スタックされているデータの数（スタックトップ） */
    int num;
    /* スタックされているデータ */
    int data[MAX_STACK_NUM];
} STACK_T;

// プロトタイプ宣言
void initStack(STACK_T *stack);
void printStack(STACK_T *stack);
void push(STACK_T* stack, int input);
int pop(STACK_T* stack);

int main(){
    
    int m;
    int input;
    int output;
    STACK_T stack;
    
    /* スタックを初期化 */
    initStack(&stack);
    
    while(1){
        
        printf("\n----------\n");
        printf("メニュー\n 1:PUSH\n 2:POP\n 3:スタック表示\n それ以外:終了\n");
        printf("----------\n");
        
        printf("input > ");
        scanf("%d", &m);
        
        /* 選ばれたメニュー (m) に応じて処理を分岐 */
        if(m == 1){
            printf("PUSHする数は？（0以上の整数のみ可） > ");
            scanf("%d", &input);
            if(input < 0){
                printf("負の数は受け付けていません\n");
                continue;
            }
            printf("%dをPUSHします\n", input);
            push(&stack, input);
            
        }else if(m == 2){
            printf("POPします\n");
            output = pop(&stack);
            if(output != -1){
                printf("%dをPOPしました\n", output);
            }
            
        } else if(m == 3){
            printf("スタックの中身を表示します\n");
            printStack(&stack);
            
        } else {
            /* 1, 2, 3以外の場合は，while文を抜け出すためにbreakを実行 */
            printf("終了します\n");
            break;
        }
    }
    
    return 0;
}

/* スタックを初期化する関数 */
void initStack(STACK_T *stack){
    int i = 0;
    stack->num = 0; // スタックが空
    for(i = 0; i < MAX_STACK_NUM; i++){
        stack->data[i] = 0;
    }
}

/* スタックの中身を表示 */
void printStack(STACK_T *stack){
    int i = 0;
    
    printf("\n");
    for(i = 0; i < stack->num; i++){
        printf("| %d |\n", stack->data[stack->num-1-i]);
        printf("-----\n");
    }
    printf("\n");
}

/* PUSHする関数 */
void push(STACK_T *stack, int input){
    
    /* スタックが満杯なら何もせず関数終了 */
    if(stack->num >= MAX_STACK_NUM){
        printf("スタックが満杯でPUSHできません\n");
        return;
    }
    
    /* データをスタックの最後に追加 */
    stack->data[stack->num] = input;
    
    /* データの数もカウントアップ (1増加)*/
    stack->num++;
}

/* POPする関数 */
int pop(STACK_T *stack){
    int ret = 0;
    
    /* スタックが空なら何もせずに関数終了 */
    if(stack->num == 0){
        printf("スタックが空です\n");
        return -1;
    }
    
    /* 一番最後にPUSHした数（配列の最後尾）を取得 */
    ret = stack->data[stack->num-1];
    
    /* POPしたのでスタックのデータの数を１つ減らす */
    stack->num--;
    
    return ret;
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmptfzk8tcf.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# 2 warnings generated.
# ----------
# メニュー
#  1:PUSH
#  2:POP
#  3:スタック表示
#  それ以外:終了
# ----------
# input > 1
# PUSHする数は？（0以上の整数のみ可） > 4
# 4をPUSHします
#
# ----------
# メニュー
#  1:PUSH
#  2:POP
#  3:スタック表示
#  それ以外:終了
# ----------
# input > 1
# PUSHする数は？（0以上の整数のみ可） > 3
# 3をPUSHします
#
# ----------
# メニュー
#  1:PUSH
#  2:POP
#  3:スタック表示
#  それ以外:終了
# ----------
# input > 4
# 終了します

# %% [markdown]
# ##
#
# 以下は配列を用いた**キュー**のプログラムである．
#
# 課題fの説明のスライドを参考にし, 正しく動作するプログラムを完成させよ．
#
# 実行結果は，
#
# - [f2-2の実行例1](課題f2-2の実行例1.txt)
# - [f2-2の実行例2](課題f2-2の実行例2.txt)
#
# と一致するようにすること．
#
# ---
# ```c
# #include <stdio.h>
# #include <string.h>
#
# /* キューに入るデータの上限 */
# #define MAX_QUEUE_NUM 10
#
# /* キュー構造体 */
# typedef struct{
#   /* エンキューされているデータの数 */
#   int num;
#   /* キューを配列dataで表現*/
#   int data[MAX_QUEUE_NUM];
# } QUEUE_T;
#
# void initQueue(QUEUE_T *queue);
# void printQueue(QUEUE_T *queue);
# void enqueue( /* コードを書く */ );
# int dequeue( /* コードを書く */ );
#
# int main(void){
#
#   int m;
#   int input;
#   int output;
#   QUEUE_T queue;
#
#   /* キューを初期化 */
#   initQueue(&queue);
#
#   while(1){
#
#     printf("\n----------\n");
#     printf("メニュー\n 1:エンキュー\n 2:デキュー\n 3:キュー表示\n それ以外:終了\n");
#     printf("----------\n");
#
#     printf("input > ");
#     scanf("%d", &m);
#
#     /* 選ばれたメニュー (m) に応じて処理を分岐 */
#     if(m == 1){
#       printf("エンキューする数は？（0以上の整数のみ可）> ");
#       scanf("%d", &input);
#       if(input < 0){
#         printf("負の数は受け付けていません\n");
#         continue;
#       }
#       printf("%dをエンキューします\n", input);
#       enqueue(&queue, input);
#     }else if(m == 2){
#       printf("デキューします\n");
#       output = dequeue(&queue);
#       if(output != -1){
#         printf("%dをデキューしました\n", output);
#       }
#     } else if(m == 3){
#       printf("キューの中身を表示します\n");
#       printQueue(&queue);
#     } else {
#       /* 1, 2, 3以外の場合はwhile文を抜け出すためにbreakを実行 */
#       printf("終了します\n");
#       break;
#     }
#   }
#   return 0;
# }
#
# /* キューを初期化する関数 */
# void initQueue(QUEUE_T *queue){
#   int i = 0;
#   queue->num = 0;
#
#   for(i = 0; i < MAX_QUEUE_NUM; i++){
#     queue->data[i] = 0;
#   }
# }
#
# /* キューの中身を表示 */
# void printQueue(QUEUE_T *queue){
#   int i = 0;
#
#   printf("(左側がキューの先頭)\n");
#   for(i = 0; i < queue->num; i++){
#     printf("%d,", queue->data[i]);
#   }
#   printf("\n");
# }
#
# /* エンキューする関数 */
# void enqueue( /* コードを書く */ ){
#
#   /* キューが満杯なら何もせず関数終了 */
#   if(queue->num >= MAX_QUEUE_NUM){
#     printf("キューが満杯でエンキューできません\n");
#     return;
#   }
#
#   // コードを書く
#
# }
#
# /* デキューする関数 */
# int dequeue( /* コードを書く */ ){
#   int i = 0;
#   int ret = 0;
#
#   /* キューが空なら何もせずに関数終了 */
#   if(queue->num == 0){
#     printf("キューが空です\n");
#     return -1;
#   }
#
#   //コードを書く
# }
#
#
# ```
# ---

# %%
#include <stdio.h>
#include <string.h>

/* キューに入るデータの上限 */
#define MAX_QUEUE_NUM 10

/* キュー構造体 */
typedef struct{
  /* エンキューされているデータの数 */
  int num;
  /* キューを配列dataで表現*/
  int data[MAX_QUEUE_NUM];
} QUEUE_T;

void initQueue(QUEUE_T *queue);
void printQueue(QUEUE_T *queue);
void enqueue(QUEUE_T *queue, int input);
int dequeue(QUEUE_T *queue);

int main(void){

  int m;
  int input;
  int output;
  QUEUE_T queue;

  /* キューを初期化 */
  initQueue(&queue);

  while(1){
      
    printf("\n----------\n");
    printf("メニュー\n 1:エンキュー\n 2:デキュー\n 3:キュー表示\n それ以外:終了\n");
    printf("----------\n");

    printf("input > ");
    scanf("%d", &m);

    /* 選ばれたメニュー (m) に応じて処理を分岐 */
    if(m == 1){
      printf("エンキューする数は？（0以上の整数のみ可）> ");
      scanf("%d", &input);
      if(input < 0){
        printf("負の数は受け付けていません\n");
        continue;
      }
      printf("%dをエンキューします\n", input);
      enqueue(&queue, input);
    }else if(m == 2){
      printf("デキューします\n");
      output = dequeue(&queue);
      if(output != -1){
        printf("%dをデキューしました\n", output);
      }
    } else if(m == 3){
      printf("キューの中身を表示します\n");
      printQueue(&queue);
    } else {
      /* 1, 2, 3以外の場合はwhile文を抜け出すためにbreakを実行 */
      printf("終了します\n");
      break;
    }
  }
  return 0;
}

/* キューを初期化する関数 */
void initQueue(QUEUE_T *queue){
  int i = 0;
  queue->num = 0;

  for(i = 0; i < MAX_QUEUE_NUM; i++){
    queue->data[i] = 0;
  }
}

/* キューの中身を表示 */
void printQueue(QUEUE_T *queue){
  int i = 0;
    
  printf("(左側がキューの先頭)\n");
  for(i = 0; i < queue->num; i++){
    printf("%d,", queue->data[i]);
  }
  printf("\n");
}

/* エンキューする関数 */
void enqueue(QUEUE_T *queue, int input){

  /* キューが満杯なら何もせず関数終了 */
  if(queue->num >= MAX_QUEUE_NUM){
    printf("キューが満杯でエンキューできません\n");
    return;
  }

  /* データをキューの最後に追加 */
  queue->data[queue->num] = input;

  /* データの数もカウントアップ */
  queue->num++;
}

/* デキューする関数 */
int dequeue(QUEUE_T *queue){
  int i = 0;
  int ret = 0;

  /* キューが空なら何もせずに関数終了 */
  if(queue->num == 0){
    printf("キューが空です\n");
    return -1;
  }

  /* デキューした数を取得 */
  ret = queue->data[0];

  /* キューのデータを一つずつ先頭側に移動 */
  for(i = 0; i < queue->num-1; i++){
    queue->data[i] = queue->data[i+1];
  }

  /* キューの最後のデータは不要になるので0で初期化 */
  queue->data[queue->num-1] = 0;

  /* デキューしたのでキューのデータの数を１つ減らす */
  queue->num--;

  return ret;
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmplur79u67.c:1:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# 2 warnings generated.
# ----------
# メニュー
#  1:エンキュー
#  2:デキュー
#  3:キュー表示
#  それ以外:終了
# ----------
# input > 1
# エンキューする数は？（0以上の整数のみ可）> 4
# 4をエンキューします
#
# ----------
# メニュー
#  1:エンキュー
#  2:デキュー
#  3:キュー表示
#  それ以外:終了
# ----------
# input > 3
# キューの中身を表示します
# (左側がキューの先頭)
# 4,
#
# ----------
# メニュー
#  1:エンキュー
#  2:デキュー
#  3:キュー表示
#  それ以外:終了
# ----------
# input > 4
# 終了します

# %%
#include <stdio.h>
#include <string.h>

/* キューに入るデータの上限 */
#define MAX_QUEUE_NUM 10

/* キュー構造体 */
typedef struct{
  /* エンキューされているデータの数 */
  int num;
  /* キューを配列dataで表現*/
  int data[MAX_QUEUE_NUM];
} QUEUE_T;

void initQueue(QUEUE_T *queue);
void printQueue(QUEUE_T *queue);
void enqueue(QUEUE_T *queue, int input);
int dequeue(QUEUE_T *queue);

int main(void){

  int m;
  int input;
  int output;
  QUEUE_T queue;

  /* キューを初期化 */
  initQueue(&queue);

  while(1){
      
    printf("\n----------\n");
    printf("メニュー\n 1:エンキュー\n 2:デキュー\n 3:キュー表示\n それ以外:終了\n");
    printf("----------\n");

    printf("input > ");
    scanf("%d", &m);

    /* 選ばれたメニュー (m) に応じて処理を分岐 */
    if(m == 1){
      printf("エンキューする数は？（0以上の整数のみ可）> ");
      scanf("%d", &input);
      if(input < 0){
        printf("負の数は受け付けていません\n");
        continue;
      }
      printf("%dをエンキューします\n", input);
      enqueue(&queue, input);
    }else if(m == 2){
      printf("デキューします\n");
      output = dequeue(&queue);
      if(output != -1){
        printf("%dをデキューしました\n", output);
      }
    } else if(m == 3){
      printf("キューの中身を表示します\n");
      printQueue(&queue);
    } else {
      /* 1, 2, 3以外の場合はwhile文を抜け出すためにbreakを実行 */
      printf("終了します\n");
      break;
    }
  }
  return 0;
}

/* キューを初期化する関数 */
void initQueue(QUEUE_T *queue){
  int i = 0;
  queue->num = 0;

  for(i = 0; i < MAX_QUEUE_NUM; i++){
    queue->data[i] = 0;
  }
}

/* エンキューする関数 */
void enqueue(QUEUE_T *queue, int input){

  /* キューが満杯なら何もせず関数終了 */
  if(queue->num >= MAX_QUEUE_NUM){
    printf("キューが満杯でエンキューできません\n");
    return;
  }

  /* データをキューの最後に追加 */
  queue->data[queue->num] = input;

  /* データの数もカウントアップ */
  queue->num++;
}

/* デキューする関数 */
int dequeue(QUEUE_T *queue){
  int i = 0;
  int ret = 0;

  /* キューが空なら何もせずに関数終了 */
  if(queue->num == 0){
    printf("キューが空です\n");
    return -1;
  }

  /* デキューした数を取得 */
  ret = queue->data[0];

  /* キューのデータを一つずつ先頭側に移動 */
  for(i = 0; i < queue->num-1; i++){
    queue->data[i] = queue->data[i+1];
  }

  /* キューの最後のデータは不要になるので0で初期化 */
  queue->data[queue->num-1] = 0;

  /* デキューしたのでキューのデータの数を１つ減らす */
  queue->num--;

  return ret;
}

/* キューの中身を表示 */
void printQueue(QUEUE_T *queue){
  int i = 0;
    
  printf("(左側がキューの先頭)\n");
  for(i = 0; i < queue->num; i++){
    printf("%d,", queue->data[i]);
  }
  printf("\n");
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmpwilz7a3w.c:1:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# 2 warnings generated.
# ----------
# メニュー
#  1:エンキュー
#  2:デキュー
#  3:キュー表示
#  それ以外:終了
# ----------
# input > 1
# エンキューする数は？（0以上の整数のみ可）> 5
# 5をエンキューします
#
# ----------
# メニュー
#  1:エンキュー
#  2:デキュー
#  3:キュー表示
#  それ以外:終了
# ----------
# input > 4
# 終了します

# %% [markdown]
# # リスト構造

# %% [markdown]
# ##
#
# 以下は，自己参照構造体を用いた単方向リストのプログラムである．
#
# **リストから引数keyに一致するデータを検索する**search_data関数を完成させよ．
#
# 実行例1
# ```
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# 検索したいデータのkeyを入力してください -> 104
# データが見つかりました
# 104 Satou
# ```
#
#
# 実行例2
# ```
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# 検索したいデータのkeyを入力してください -> 107
# データが見つかりませんでした
# ```

# %% [markdown]
# ```c
# // f3-1.cのコード
# #include <stdio.h>
# #include <string.h>
# #include <stdlib.h>
#
# // 自己参照構造体の宣言
# typedef struct node {
#     int key;
#     char name[7];
#     struct node *next;
# }node_t;
#
# // リストの末尾にデータを追加する関数
# node_t *add_node_tail(int key, char name[7], node_t *head);
#
# // リストのデータを先頭から順に表示する関数
# void print_node(node_t *head);
#
# // 引数keyに一致するデータを検索し表示する関数
# void search_data(node_t *p, int key);
#
# int main(){
#     int key;
#     node_t *head; // リストの先頭を指すポインタ
#     head = NULL; // 最初はリストは空なので，headにNULLを設定
#
#     head = add_node_tail(101, "Tanaka", head);
#     head = add_node_tail(102, "Yamada", head);
#     head = add_node_tail(103, "Itou", head);
#     head = add_node_tail(104, "Satou", head);
#     head = add_node_tail(105, "Abe", head);
#
#     // リストのデータを表示
#     print_node(head);
#
#     printf("検索したいデータのkeyを入力してください -> ");
#     scanf("%d", &key);
#     search_data(head, key);
#
#     return 0;
# }
#
# void search_data(node_t *p, int key){
#
#     /* コードを書く */
# }
#
# node_t *add_node_tail(int key, char name[7], node_t *h){
#     node_t *p;
#     node_t *head=h;
#
#     // ノード一つ分のデータ領域を確保
#     if((p = (node_t *)malloc(sizeof( node_t)))==NULL){
#         printf("malloc error");
#         exit(1);
#     }
#
#     // 生成したノードにデータを代入
#     p->key = key;
#     strcpy(p->name, name);
#     p->next = NULL;
#
#     if(head==NULL){  // まだリストが空の場合
#         return p;  // headを更新
#     }
#     else{ // リストに既にデータがある場合
#
#         // リストの末尾までポインタを進める
#         while(h->next!=NULL){
#             h = h->next;
#         }
#         h->next = p;
#
#         return head; // headはそのまま
#     }
#
# }
#
# void print_node(node_t *p){
#
#     printf("ID, name\n");
#     while(p!=NULL){
#         printf("%d %s\n",p->key, p->name);
#         p = p->next;
#     }
# }
# ```

# %%
//　解答
#include <stdio.h>
#include <string.h>
#include <stdlib.h>

// 自己参照構造体の宣言
typedef struct node {
    int key;
    char name[7];
    struct node *next;
}node_t;

// リストの末尾にデータを追加する関数
node_t *add_node_tail(int key, char name[7], node_t *head);

// リストのデータを先頭から順に表示する関数
void print_node(node_t *head);

// 引数keyに一致するデータを検索し表示する関数
void search_data(node_t *p, int key);

int main(){
    int key;
    node_t *head; // リストの先頭を指すポインタ
    head = NULL; // 最初はリストは空なので，headにNULLを設定
    
    head = add_node_tail(101, "Tanaka", head);
    head = add_node_tail(102, "Yamada", head);
    head = add_node_tail(103, "Itou", head);
    head = add_node_tail(104, "Satou", head);
    head = add_node_tail(105, "Abe", head);
    
    // リストのデータを表示
    print_node(head);
    
    printf("検索したいデータのkeyを入力してください -> ");
    scanf("%d", &key);
    search_data(head, key);
    
    return 0;
}

void search_data(node_t *p, int key){
    while(p!=NULL){
        if (p->key == key){
            printf("データが見つかりました\n");
            printf("%d %s\n",p->key, p->name);
            return;
        }
        p = p->next;
    }
    printf("データが見つかりませんでした\n");
}

node_t *add_node_tail(int key, char name[7], node_t *h){
    node_t *p;
    node_t *head=h;
    
    // ノード一つ分のデータ領域を確保
    if((p = (node_t *)malloc(sizeof( node_t)))==NULL){
        printf("malloc error");
        exit(1);
    }
    
    // 生成したノードにデータを代入
    p->key = key;
    strcpy(p->name, name);
    p->next = NULL;
    
    if(head==NULL){  // まだリストが空の場合
        return p;  // headを更新
    }
    else{ // リストに既にデータがある場合
        
        // リストの末尾までポインタを進める
        while(h->next!=NULL){
            h = h->next;
        }
        h->next = p;
        
        return head; // headはそのまま
    }
    
}

void print_node(node_t *p){
    
    printf("ID, name\n");
    while(p!=NULL){
        printf("%d %s\n",p->key, p->name);
        p = p->next;
    }
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmp59r8jv58.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# 検索したいデータのkeyを入力してください -> 102
# データが見つかりました
# 102 Yamada

# %% [markdown]
# ##
#
#
# 以下は，自己参照構造体を用いた単方向リストのプログラムである．
#
# **リストから引数keyに一致するデータを削除する**delete_data関数を完成させよ．
#
#
# 実行例1
# ```
# 削除前
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# 削除したいデータのkeyを入力してください -> 104
#
# 削除後
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 105 Abe
# ```
#
# 実行例2
# ```
# 削除前
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# 削除したいデータのkeyを入力してください -> 101
#
# 削除後
# ID, name
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# ```

# %% [markdown]
# ---
# ```c
# // f3-2.cのコード
# #include <stdio.h>
# #include <string.h>
# #include <stdlib.h>
#
# // 自己参照構造体の宣言
# typedef struct node {
#     int key;
#     char name[7];
#     struct node *next;
# }node_t;
#
# // リストの末尾にデータを追加する関数
# node_t *add_node_tail(int key, char name[7], node_t *head);
#
# // リストのデータを先頭から順に表示する関数
# void print_node(node_t *head);
#
# // 引数keyに一致するデータを検索し削除する関数
# node_t * delete_data(node_t *p, int key);
#
# int main(){
#     int key;
#     node_t *head; // リストの先頭を指すポインタ
#     head = NULL; // 最初はリストは空なので，headにNULLを設定
#
#     head = add_node_tail(101, "Tanaka", head);
#     head = add_node_tail(102, "Yamada", head);
#     head = add_node_tail(103, "Itou", head);
#     head = add_node_tail(104, "Satou", head);
#     head = add_node_tail(105, "Abe", head);
#
#     printf("削除前\n");
#     // リストのデータを表示
#     print_node(head);
#
#     printf("削除したいデータのkeyを入力してください -> ");
#     scanf("%d", &key);
#     head = delete_data(head, key);
#
#     printf("\n削除後\n");
#     // リストのデータを表示
#     print_node(head);
#
#     return 0;
# }
#
# node_t * delete_data(node_t *p, int key){
#     node_t *h = p;
#     if(p->key == key){  // 削除データが先頭
#
#         // 先頭を飛ばして次のノードをheadにする
#         return p->next;
#
#     }
#     else{  // 削除データが先頭以外
#         while(p!=NULL){
#
#             // 削除データの手前までポインタを進める
#             if (p->next->key == key){
#
#                 //　現在のノードから削除データを飛ばしたノードに繋ぐ
#                 p->next = p->next->next;
#                 return h; // headは変わらない
#             }
#             p = p->next;
#         }
#
#         printf("削除対象のデータが存在しません\n");
#         return h; // headは変わらない
#
#     }
#
# }
#
# node_t *add_node_tail(int key, char name[7], node_t *h){
#     node_t *p;
#     node_t *head=h;
#
#     // ノード一つ分のデータ領域を確保
#     if((p = (node_t *)malloc(sizeof( node_t)))==NULL){
#         printf("malloc error");
#         exit(1);
#     }
#
#     // 生成したノードにデータを代入
#     p->key = key;
#     strcpy(p->name, name);
#     p->next = NULL;
#
#     if(head==NULL){  // まだリストが空の場合
#         return p;  // headを更新
#     }
#     else{ // リストに既にデータがある場合
#
#         // リストの末尾までポインタを進める
#         while(h->next!=NULL){
#             h = h->next;
#         }
#         h->next = p;
#
#         return head; // headはそのまま
#     }
#
# }
#
# void print_node(node_t *p){
#
#     printf("ID, name\n");
#     while(p!=NULL){
#         printf("%d %s\n",p->key, p->name);
#         p = p->next;
#     }
# }
# ```
# ---

# %%
// f3-2.c 解答
#include <stdio.h>
#include <string.h>
#include <stdlib.h>

// 自己参照構造体の宣言
typedef struct node {
    int key;
    char name[7];
    struct node *next;
}node_t;

// リストの末尾にデータを追加する関数
node_t *add_node_tail(int key, char name[7], node_t *head);

// リストのデータを先頭から順に表示する関数
void print_node(node_t *head);

// 引数keyに一致するデータを検索し削除する関数
node_t * delete_data(node_t *p, int key);

int main(){
    int key;
    node_t *head; // リストの先頭を指すポインタ
    head = NULL; // 最初はリストは空なので，headにNULLを設定
    
    head = add_node_tail(101, "Tanaka", head);
    head = add_node_tail(102, "Yamada", head);
    head = add_node_tail(103, "Itou", head);
    head = add_node_tail(104, "Satou", head);
    head = add_node_tail(105, "Abe", head);
    
    printf("削除前\n");
    // リストのデータを表示
    print_node(head);
    
    printf("削除したいデータのkeyを入力してください -> ");
    scanf("%d", &key);
    head = delete_data(head, key);
    
    printf("\n削除後\n");
    // リストのデータを表示
    print_node(head);
    
    return 0;
}

node_t * delete_data(node_t *p, int key){
    node_t *h = p;
    if(p->key == key){  // 削除データが先頭

        // 先頭を飛ばして次のノードをheadにする
        return p->next;
        
    }
    else{  // 削除データが先頭以外
        while(p!=NULL){
            
            // 削除データの手前までポインタを進める
            if (p->next->key == key){
                
                //　現在のノードから削除データを飛ばしたノードに繋ぐ
                p->next = p->next->next;
                return h; // headは変わらない
            }
            p = p->next;
        }
        
        printf("削除対象のデータが存在しません\n");
        return h; // headは変わらない
        
    }
    
}

node_t *add_node_tail(int key, char name[7], node_t *h){
    node_t *p;
    node_t *head=h;
    
    // ノード一つ分のデータ領域を確保
    if((p = (node_t *)malloc(sizeof( node_t)))==NULL){
        printf("malloc error");
        exit(1);
    }
    
    // 生成したノードにデータを代入
    p->key = key;
    strcpy(p->name, name);
    p->next = NULL;
    
    if(head==NULL){  // まだリストが空の場合
        return p;  // headを更新
    }
    else{ // リストに既にデータがある場合
        
        // リストの末尾までポインタを進める
        while(h->next!=NULL){
            h = h->next;
        }
        h->next = p;
        
        return head; // headはそのまま
    }
    
}

void print_node(node_t *p){
    
    printf("ID, name\n");
    while(p!=NULL){
        printf("%d %s\n",p->key, p->name);
        p = p->next;
    }
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmp6d0tyh5h.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# 削除前
# ID, name
# 101 Tanaka
# 102 Yamada
# 103 Itou
# 104 Satou
# 105 Abe
# 削除したいデータのkeyを入力してください -> 103
#
# 削除後
# ID, name
# 101 Tanaka
# 102 Yamada
# 104 Satou
# 105 Abe

# %% [markdown]
# # 再帰関数

# %% [markdown]
# ##
#
# 以下は， 階乗値 n! を再帰関数を用いて求めるプログラムである．
#
# 実行例と同様の結果となるように，プログラムを完成させよ．
#
# - 実行例1 (n = 3)
#
# ans = 6
#
# - 実行例2 (n = 5)
#
# ans = 120
#
# ---
#
# ```c
# // f4-1.cのコード
# #include<stdio.h>
# #include <stdlib.h>
#
# //階乗値n!を再帰関数を用いて求めるプログラム
#
# int func_factorial( /* コードを書く */ );
#
# int main(){
#     int ans;
#
#     // 再帰関数を呼び出し結果を受け取る
#
#     printf("ans = %d\n", ans);
# }
#
# int func_factorial( /* コードを書く */ ){
#
#     // 再帰関数の中身を書く
# }
#
# ```
# ---

# %%
// f4.1.c 解答
#include<stdio.h>
#include <stdlib.h>

//階乗値n!を再帰関数を用いて求めるプログラム

int func_factorial(int n);

int main(){
    int ans;
    ans=func_factorial(5);
    printf("ans = %d\n", ans);
    
    return 0;
}

int func_factorial(int n){
    
    // printf("n=%d\n",n);
    if(n==1){
        return 1;
    }else{
        return func_factorial(n-1)*n;
    }
}
# Out:
# ans = 120

# %% [markdown]
# ##
#
# 以下は， ユークリッドの互除法(**非再帰版**)のプログラムである．
#
# 実行例と同様の結果となるように，プログラムを完成させよ．
#
#
# - 実行例1
# ```
# 自然数(a, b) = (1071, 1029)
# 1071を1029で割った余りは42
# 1029を42で割った余りは21
# 42を21で割った余りは0
# 最大公約数 = 21
# ```
#
# - 実行例2
# ```
# 自然数(a, b) = (3059,2337)
# 3059を2337で割った余りは722
# 2337を722で割った余りは171
# 722を171で割った余りは38
# 171を38で割った余りは19
# 38を19で割った余りは0
# 最大公約数 = 19
# ```
#
# ---
# ```c
# #include <stdio.h>
#
# // ユークリッドの互除法(非再帰版)
#
# int main(void)
# {
#
#     int a, b, r, tmp;
#
#     a=1071;
#     b=1029;
#     printf("自然数(a, b) = (%d, %d)\n", a, b);
#
#     // aとbのうち，小さい方がbとなるようにする．
#     if(a<b){
#         tmp = a;
#         a = b;
#         b = tmp;
#     }
#
#     //while文を使うこと
#     while(1){
#         // コードを書く
#
#     }
#
#     // 最大公約数を表示
#
#     return 0;
# }
# ```
# ---

# %%
// f4-2.c 解答
#include <stdio.h>

// ユークリッドの互除法(非再帰版)

int main(void)
{
    
    int a, b, r, tmp;
    
    a=1071;
    b=1029;
    
//     a=3059;
//     b=2337;
    printf("自然数(a, b) = (%d,%d)\n", a, b);


    //aとbのうち，小さい方がbとなるようにする．
    if(a<b){
        tmp = a;
        a = b;
        b = tmp;
    }
    
    while(1){
        r = a % b;
        printf("%dを%dで割った余りは%d\n", a, b, r);
        if(r==0)
            break;
        
        a = b;
        b = r;
     
    }
    
    printf("最大公約数 = %d\n", b);
    
    return 0;
}
# Out:
# 自然数(a, b) = (1071,1029)
# 1071を1029で割った余りは42
# 1029を42で割った余りは21
# 42を21で割った余りは0
# 最大公約数 = 21

# %% [markdown]
# ##
#
# 以下は， ユークリッドの互除法(**再帰版**)のプログラムである．
#
# 実行例と同様の結果となるように，プログラムを完成させよ．
#
#
# - 実行例1
#
# ```
# 自然数(a, b) = (1071,1029)
# x = 1071, y = 1029
# x = 1029, y = 42
# x = 42, y = 21
# x = 21, y = 0
# 最大公約数 = 21
# ```
#
# - 実行例2
#
# ```
# 自然数(a, b) = (3059, 2337)
# x = 3059, y = 2337
# x = 2337, y = 722
# x = 722, y = 171
# x = 171, y = 38
# x = 38, y = 19
# x = 19, y = 0
# 最大公約数 = 19
#
# ```
#
# ---
# ```c
# //　f4-3.cのコード
# #include <stdio.h>
#
# // ユークリッドの互除法(再帰版)
#
# int gcd( /*コードを書く*/ );
#
# int main(void)
# {
#
#     int a, b, tmp, ans;
#
#     a=1071;
#     b=1029;
#
#     printf("自然数(a, b) = (%d, %d)\n", a, b);
#
#     // aとbのうち，小さい方がbとなるようにする．
#     if(a<b){
#         tmp = a;
#         a = b;
#         b = tmp;
#     }
#
#      // 再帰関数を呼び出し結果を受け取る
#
#     printf("最大公約数 = %d\n", ans);
#
#     return 0;
# }
#
# int gcd( /*コードを書く*/ )
# {
#     // 再帰関数の中身を書く
# }
# ```
# ---

# %%
// f4-3.c 解答
#include <stdio.h>

// ユークリッドの互除法(再帰版)

int gcd(int x, int y);

int main(void)
{
    
    int a, b, tmp, ans;
    
    a=1071;
    b=1029;
//     a=3059;
//     b=2337;
    
    printf("自然数(a, b) = (%d, %d)\n", a, b);
    
    // aとbのうち，小さい方がbとなるようにする．
    if(a<b){
        tmp = a;
        a = b;
        b = tmp;
    }
    
    // 再帰関数の呼び出し
    ans=gcd(a,b);
    printf("最大公約数 = %d\n", ans);
    
    return 0;
}

int gcd(int x, int y)
{
    printf("x = %d, y = %d\n", x, y);
    if (y == 0) {
        return x;
    } else {
        return gcd(y, x % y);
    }
}
# Out:
# 自然数(a, b) = (1071, 1029)
# x = 1071, y = 1029
# x = 1029, y = 42
# x = 42, y = 21
# x = 21, y = 0
# 最大公約数 = 21

# %% [markdown]
# ##
#
# 𝑛段の階段がある．この階段を登るとき, １段か２段ずつしか上がらないことにする．
#
# このとき，**何通りの登り方があるか**を計算するプログラムを作成せよ．
#
# ただし再帰関数を用いること．
#
# ---
# ```c
# // f4-4.cのコード
# #include<stdio.h>
# #include<stdlib.h>
#
# //階段の問題
#
# int count( /* コードを書く */ );
#
# int main(){
#
#     // 再帰関数の呼び出し
#
#     return 0;
# }
#
# int count(int n){
#
#     // 再帰関数の中身を書く
#
# }
# ```
# ---

# %%
// f4-4.c 解答
// 階段の問題
#include<stdio.h>
#include <stdlib.h>

int count(int n);

int main(){
    int ans;
    ans=count(5);
    printf("ans=%d\n",ans);
}

int count(int n){
    // printf("n=%d\n",n);
    if(n==1)
        return 1;
    else if(n==2)
        return 2;
    else
        return( count(n-1) + count(n-2) );
}
# Out:
# ans=8

# %% [markdown]
# # ソート

# %% [markdown]
# ##
#
#
# 以下は，構造体配列のデータをソートするプログラムである．
#
# 課題のスライドを参考しに，プログラムを完成させよ．
#
# ---
# ```c
# // f5-1.cのコード
# #include <stdio.h>
# #include <stdlib.h>
# #include <string.h>
#
# typedef struct{
#     int no;
#     char name[5];
#     int score1;
#     int score2;
#     double point;
# }student_t;
#
# void print_data(student_t *seito, int n);
#
# // 関数のプロトタイプ宣言を追加
#
# int main()
# {
#     int mode;
#     int n = 5; // データ数
#     // 構造体配列の宣言と初期化
#     student_t seito[5]={
#         {1001, "Taka", 75, 60, 65.1},
#         {1002, "Miki", 81, 34, 56.8},
#         {1003, "Taro", 79, 56, 67.9},
#         {1004, "Jiro", 80, 67, 87.4},
#         {1005, "Yuki", 93, 89, 95.2}
#         };
#
#     // ソート前のデータを表示
#     print_data(seito, n);
#
#     printf("select mode [1, 2, 3] ->  ");
#     scanf("%d", &mode);
#
#     // mode によりソートの方法を選択
#     switch (mode){
#         case 1:
#             printf("score1をキーとして昇順にソート\n\n");
#             // 関数を呼び出す
#             break;
#
#         case 2:
#             printf("score2をキーとして降順にソート\n\n");
#             // 関数を呼び出す
#             break;
#
#         case 3:
#             printf("pointをキーとして降順にソート\n\n");
#             // 関数を呼び出す
#             break;
#
#         default:
#             printf("error -> input [1, 2, 3]\n");
#             exit (1);
#     }
#
#     // ソート後のデータを表示
#     print_data(seito, n);
#
#     return 0;
# }
#
# // 構造体配列を表示する関数
# void print_data(student_t *seito, int n){
#     int i;
#
#     printf("no, name, score1, score2, point\n");
#     for(i = 0; i<n; i++)
#         printf("%d, %s, %d, %d, %.1f\n",seito[i].no, seito[i].name, seito[i].score1, seito[i].score2, seito[i].point);
#     printf("\n");
#
# }
#
# // 構造体用のswap関数
# void swap(student_t *a, student_t *b){
#     student_t temp;
#
#     temp = *a;
#     *a = *b;
#     *b = temp;
#
# }
#
# // score1をキーとして昇順にソートする関数を作成
#
#
# // score2をキーとして降順にソートする関数を作成
#
#
# // pointをキーとして降順にソートする関数を作成
#
#
# ```
# ---

# %%
// f5-1.c 解答
#include <stdio.h>
#include <stdlib.h>
#include <string.h>

typedef struct{
    int no;
    char name[5];
    int score1;
    int score2;
    double point;
}student_t;

void print_data(student_t *seito, int n);
void swap(student_t *a, student_t *b);

void Sort1(student_t *seito, int n);
void Sort2(student_t *seito, int n);
void Sort3(student_t *seito, int n);

int main()
{
    int mode;
    int n = 5; // データ数
    // 構造体配列の宣言と初期化
    student_t seito[5]={
        {1001, "Taka", 75, 60, 65.1},
        {1002, "Miki", 81, 34, 56.8},
        {1003, "Taro", 79, 56, 67.9},
        {1004, "Jiro", 80, 67, 87.4},
        {1005, "Yuki", 93, 89, 95.2}
        };
    
    // ソート前のデータを表示
    print_data(seito, n);
    
    printf("select mode [1, 2, 3] ->  ");
    scanf("%d", &mode);
    
    // modeによりソートの方法を選択
    switch (mode){
        case 1:
            printf("score1をキーとして昇順にソート\n\n");
            Sort1(seito, n);
            break;
            
        case 2:
            printf("score2をキーとして降順にソート\n\n");
            Sort2(seito, n);
            break;
            
        case 3:
            printf("pointをキーとして降順にソート\n\n");
            Sort3(seito, n);
            break;
            
        default:
            printf("error -> input [1, 2, 3]\n");
            exit (1);      
    }
    
    // ソート後のデータを表示
    print_data(seito, n);
    
    return 0;
}

// 構造体配列を表示する関数
void print_data(student_t *seito, int n){
    int i;
    
    printf("no, name, score1, score2, point\n");
    for(i = 0; i<n; i++)
        printf("%d, %s, %d, %d, %.1f\n",seito[i].no, seito[i].name, seito[i].score1, seito[i].score2, seito[i].point);
    printf("\n");
    
}

// 構造体用のswap関数
void swap(student_t *a, student_t *b){
    student_t temp;
    
    temp = *a;
    *a = *b;
    *b = temp;
    
}

// score1をキーとして昇順にソート
// バブルソート
void Sort1(student_t *seito, int n){
    int i,j;
    
    //BubbleSort
    for(i=0; i<n-1; i++){
        for(j=n-1; j>i; j--){
            if(seito[j-1].score1>seito[j].score1)
                swap( &seito[j], &seito[j-1]);
        }
    }
}

// score2をキーとして降順にソート
// バブルソート
void Sort2(student_t *seito, int n){
    int i,j;
    
    //BubbleSort
    for(i=0; i<n-1; i++){
        for(j=n-1; j>i; j--){
            if(seito[j-1].score2<seito[j].score2)
                swap( &seito[j], &seito[j-1]);
        }
    }
}

// pointをキーとして降順にソート
// バブルソート
void Sort3(student_t *seito, int n){
    int i,j;
    
    //BubbleSort
    for(i=0; i<n-1; i++){
        for(j=n-1; j>i; j--){
            if(seito[j-1].point<seito[j].point)
                swap( &seito[j], &seito[j-1]);
        }
    }
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmpeekhoxur.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# no, name, score1, score2, point
# 1001, Taka, 75, 60, 65.1
# 1002, Miki, 81, 34, 56.8
# 1003, Taro, 79, 56, 67.9
# 1004, Jiro, 80, 67, 87.4
# 1005, Yuki, 93, 89, 95.2
#
# select mode [1, 2, 3] ->  1
# score1をキーとして昇順にソート
#
# no, name, score1, score2, point
# 1001, Taka, 75, 60, 65.1
# 1003, Taro, 79, 56, 67.9
# 1004, Jiro, 80, 67, 87.4
# 1002, Miki, 81, 34, 56.8
# 1005, Yuki, 93, 89, 95.2

# %% [markdown]
# # アルゴリズム
#
# 基本情報などの問題

# %% [markdown]
# ##
#
# 基本情報技術者平成20年春期 午前問15
#
# https://www.fe-siken.com/kakomon/20_haru/q15.html
#
# **引き算の繰返しによるユークリッドの互除法のフローチャート**を参考にし，以下のプログラムを完成させよ．
#
# なお，比較回数も出力させよ．
#
# ---
# ```c
#
# // f4-5のコード
# // ユークリッドの互除法 (引き算の繰返し)
# #include<stdio.h>
#
# int main(){
#     int A = 876, B = 204;
#     int L, S;
#     int count =0; //比較回数をカウントするための変数
#
#     // コードを書く
#
#     printf("A = %d\n", A);
#     printf("B = %d\n", B);
#     printf("L = %d\n", L);
#     printf("比較回数 = %d\n", count);
#
#     return 0;
# }
# ```
# ---

# %%
// f5-1.c 解答
// ユークリッドの互除法 (引き算の繰返し)
#include<stdio.h>

int main(){
    int A = 876, B = 204;
    int L, S;
    int count =0; //比較回数をカウントするための変数
    
    L = A;
    S = B;
    while(1){
        
        count++;
        if(L==S){
            break;
            
        }else if(L>S){
            L = L - S;
        }else{
            S = S - L;
        }
        
    }
    printf("A = %d\n", A);
    printf("B = %d\n", B);
    printf("L = %d\n", L);
    printf("比較回数 = %d\n", count);
    
    return 0;
}
# Out:
# A = 876
# B = 204
# L = 12
# 比較回数 = 11

# %% [markdown]
# ##
#
#
# 基本情報技術者平成26年秋期 午前問7
#
# https://www.fe-siken.com/kakomon/26_aki/q7.html
#
# 次の関数 f(n, k)がある．
#
# **f(4, 2)の値を確認する**ためのプログラムを作成せよ．
#
#
# $\displaystyle f( n,k) =\begin{cases}
# 1 & ( k=0)\\
# f( n-1,k-1) +f( n-1,k) & ( 0< k< n)\\
# 1 & ( k=n)
# \end{cases} \ $

# %%
// 解答 
#include<stdio.h>

int func(int n, int k);

int main(){
    int ans;
    ans = func(4, 2);
    printf("f(4, 2) = %d", ans);
    return 0;
}

int func(int n, int k){
    if(k == 0)
        return 1;
    else if(0 < k && k < n)
        return func(n-1, k-1) + func(n-1, k);
    else
        return 1;
}
# Out:
# f(4, 2) = 6

# %% [markdown]
# ##
#
# 応用情報技術者平成24年秋期 午前問7
#
# https://www.ap-siken.com/kakomon/24_aki/q7.html
#
# 次の関数g(x)の定義に従ってg(4)を再帰的に求めるとき，**必要な加算の回数は幾らになるか**を確認するためのプログラムを作成せよ．
#
# $\displaystyle  \begin{array}{{>{\displaystyle}l}}
# g( x) \ =\mathrm{if} \ x< 2\ \mathrm{then} \ 1\\
# \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \mathrm{else} \ g( x-1) +g( x-2)
# \end{array}$
#
#
#
#
#
# ヒント:  C言語 再帰呼び出し回数

# %%
// 解答 
#include<stdio.h>

int func(int x);

int count = 0;

int main(){
    int ans;
    ans = func(4);
    printf("g(4) = %d\n", ans);
    printf("count = %d\n", count);
    return 0;
}

int func(int x){
    if(x < 2)
        return 1;
    else{
        count++;
        return func(x-1) + func(x-2);
    }
}
# Out:
# g(4) = 5
# count = 4

# %% [markdown]
# ##
#
# 基本情報技術者平成16年春期 午前問14
#
# https://www.fe-siken.com/kakomon/16_haru/q14.html
#
# 非負の整数nに対して次のとおりに定義された関数F(n)，G(n)がある．
#
# **F(5)の値は幾らになるか**を確認するプログラムを完成させよ．
#
#
#
# $\displaystyle  \begin{array}{{>{\displaystyle}l}}
# F( n) :\mathrm{\ if} \ n\leqq 1\ \mathrm{then\ return} \ 1\ \mathrm{else\ return} \ n\times G( n－1)\\
# G( n) :\ \mathrm{if} \ n＝0\ \mathrm{then\ return} \ 0\ \mathrm{else\ return} \ n＋F( n－1)
# \end{array}$

# %%
// 解答 
#include<stdio.h>

int func_f(int x);
int func_g(int x);

int main(){
    int ans;
    ans = func_f(5);
    printf("f(5) = %d\n", ans);
    return 0;
}

int func_f(int n){
    if(n <= 1)
        return 1;
    else{
        return n * func_g(n-1);
    }
}

int func_g(int n){
    if(n == 0)
        return 1;
    else{
        return n + func_f(n-1);
    }
}
# Out:
# f(5) = 65

# %% [markdown]
# ##
#
# ソフトウェア開発技術者平成17年春期 午前問14
#
# https://www.ap-siken.com/kakomon/17_haru/q14.html
#
# リンク先の流れ図を実行したとき，手続が終了するまでに**何回の比較を行うか**を確認するプログラムを完成させよ．

# %%
// 解答 
#include<stdio.h>

int main(){
    int x = 0, y = 0;
    int count = 0;
    
    while(1){
        
        count++;
        if(x > 5000)
            break;
        
        x = x + y;
        y = y + 1;

    }
    
    printf("count = %d\n", count);

    return 0;
}
# Out:
# count = 102

# %% [markdown]
# ##
#
# 基本情報技術者平成17年春期 午前問1
#
# https://www.fe-siken.com/kakomon/17_haru/q1.html
#
# リンク先の流れ図は, 10進整数 j (0＜j＜100) を8けたの2進数に変換する処理を表している．
#
# 2進数は下位けたから順に, 配列の要素 NISHIN(1) から NISHIN(8) に格納される．
#
# 流れ図に従うように，**10進整数から2進数に変換する**プログラムを作成せよ．
#
# ただし，以下の実行結果のように変換された2進数を表示させること．
#
#
# - 実行結果1
# ```
# input j -> 5
# 00000101
# ```
#
# - 実行結果2
# ```
# input j -> 10
# 00001010
# ```
#
# - 実行結果3
# ```
# input j -> 50
# 00110010
# ```

# %%
// 解答 
#include<stdio.h>

int main(){
    int i, j;
    int NSHIN[9];
    
    printf("input j -> ");
    scanf("%d", &j);
    
    for(i =1; i <= 8; i++){
        
        NSHIN[i] = j % 2;
        j = j / 2; 
        
    }
    
    // NISHIN[1] が最下位ビット(一番右)
    // NISHIN[8] が最上位ビット(一番左)
    for(i =1; i <= 8; i++){
        printf("%d", NSHIN[9 - i]);
    }
    return 0;
}
# Out:
# In file included from /var/folders/17/1fkqsg691_3flnsv7g5_wrz80000gn/T/tmpvyx9g6sa.c:2:
# /Users/kushida/Desktop/tmp/jupyter-c-kernel/jupyter_c_kernel/resources/stdio_wrap.h:279:47: warning: token pasting of ',' and __VA_ARGS__ is a GNU extension [-Wgnu-zero-variadic-macro-arguments]
# #define scanf(format, ...) scanf_wrap(format, ##__VA_ARGS__, &scanf_wrap_number_read)
#                                               ^
# 1 warning generated.
# input j -> 50
# 00110010

# %% [markdown]
# ##
#
# 応用情報技術者平成25年秋期 午前問1
#
# https://www.ap-siken.com/kakomon/25_aki/q1.html
#
# 会員を4桁の会員番号で管理している小売店がある。会員の中には，4と9の数字を嫌う人がいるとの理由で，会員番号は，0001，0002，0003，0005，…のように，この二つの数字を使わないように連番で発行している．
#
# 会員番号を0001から0528まで発行したとき，**会員番号を付与した会員数は何人か**を確認するプログラムを作成せよ．

# %%
// f6-7.c 解答
#include <stdio.h>

int main()
{
    int i, j, k;
    int count=0;
    
    // 会員番号を 100*i + 10*j + k で示し，カウントしていく
    
    // 100の桁
    for(i=0;i<10;i++){
        // 数字に4 or 9が出る場合はスキップ(カウントしない)
        if(i == 4 || i == 9)
            continue;
        
        // 10の桁
        for(j=0;j<10;j++){
            
            if(j == 4 || j == 9)
                continue;
            
            // 1の桁
            for(k=0;k<10;k++){
                if(k == 4 || k == 9)
                    continue;
                
                // 会員番号0000はスキップ
                if(i == 0 && j ==0 && k==0)
                    continue;
        
                count++;
                
                // 会員番号が528になったら終了
                 if(i == 5 && j ==2 && k==8){
                     printf("count = %d\n", count);
                     return 0;
                 }
            }
        }
        
    }
        
    return 0;
}
# Out:
# count = 279

# %% [markdown]
# ##
#
# 応用情報技術者令和元年秋期 午前問1
#
# https://www.ap-siken.com/kakomon/01_aki/q1.html
#
# あるホテルは客室を1,000部屋もち，部屋番号は，数字4と9を使用しないで0001から順に数字4桁の番号としている．
#
# (1) 部屋番号が0330の部屋は何番目の部屋か
#
# (2) 500番目の部屋の部屋番号
#
# を確認するプログラムを作成せよ．
#
#
# 実行例
#
# ```
# 部屋番号が0330の部屋は216番目の部屋
# 500番目の部屋の部屋番号は0875
# ```

# %%
// f6-8.c 解答
#include <stdio.h>

int main()
{
    int i, j, k;
    int count=0;
    
    // 部屋番号を 100*i + 10*j + k で示し，カウントしていく
    
    // 100の桁
    for(i=0;i<10;i++){
        // 数字に4 or 9が出る場合はスキップ(カウントしない)
        if(i == 4 || i == 9)
            continue;
        
        // 10の桁
        for(j=0;j<10;j++){
            
            if(j == 4 || j == 9)
                continue;
            
            // 1の桁
            for(k=0;k<10;k++){
                if(k == 4 || k == 9)
                    continue;
                
                if(i == 0 && j ==0 && k==0)
                    continue;
        
                count++;
                
                if(i == 3 && j == 3 && k == 0 )
                    printf("部屋番号が0330の部屋は%d番目の部屋\n", count);
                
                if(count == 500)
                    printf("500番目の部屋の部屋番号は0%d%d%d\n", i, j, k);
                
            }
        }
        
    }
    
    return 0;
}
# Out:
# 部屋番号が0330の部屋は216番目の部屋
# 500番目の部屋の部屋番号は0875
